# %%
import pandas as pd

bonn_split_data = pd.read_csv('/home/s17gmikh/FCD-Detection/meld_graph/data/preprocessed/BONN_splits_full_test.csv')
bonn_split = bonn_split_data[bonn_split_data['split'] == 'test']['subject_id'].tolist()
bonn_split
# Out:
# ['MELD_H101_3T_FCD_00058',
#  'MELD_H101_3T_FCD_00043',
#  'MELD_H101_3T_FCD_00133',
#  'MELD_H101_3T_FCD_00060',
#  'MELD_H101_3T_FCD_00047',
#  'MELD_H101_3T_FCD_00132',
#  'MELD_H101_3T_FCD_00059',
#  'MELD_H101_3T_FCD_00050',
#  'MELD_H101_3T_FCD_00027',
#  'MELD_H101_3T_FCD_00116',
#  'MELD_H101_3T_FCD_00066',
#  'MELD_H101_3T_FCD_00090',
#  'MELD_H101_3T_FCD_00063',
#  'MELD_H101_3T_FCD_00120',
#  'MELD_H101_3T_FCD_00048',
#  'MELD_H101_3T_FCD_00040',
#  'MELD_H101_3T_FCD_00064',
#  'MELD_H101_3T_FCD_00098',
#  'MELD_H101_3T_FCD_00061',
#  'MELD_H101_3T_FCD_00092',
#  'MELD_H101_3T_FCD_00087',
#  'MELD_H101_3T_FCD_00099',
#  'MELD_H101_3T_FCD_00032',
#  'MELD_H101_3T_FCD_00089',
#  'MELD_H101_3T_FCD_00038',
#  'MELD_H101_3T_FCD_00121',
#  'MELD_H101_3T_FCD_00024',
#  'MELD_H101_3T_FCD_00033',
#  'MELD_H101_3T_FCD_00130',
#  'MELD_H101_3T_FCD_00141',
#  'MELD_H101_3T_FCD_00072',
#  'MELD_H101_3T_FCD_00016',
#  'MELD_H101_3T_FCD_00136',
#  'MELD_H101_3T_FCD_00097',
# ...

# %%
import nibabel as nib
import numpy as np

a = nib.load("/home/mikhelson/FCD-Detection/meld_graph/data/input/MELD_H101_3T_FCD_00043/xhemi/classifier/rh.prediction.mgz").get_fdata()
b = nib.load("/home/mikhelson/FCD-Detection/meld_graph/data/input/MELD_H101_3T_FCD_00058/xhemi/classifier/rh.prediction.mgz").get_fdata()

np.allclose(a, b)   # должно быть False
np.sum(a), np.sum(b)
# Out:
# (np.float64(5795.375426595623), np.float64(84.03139767781249))
